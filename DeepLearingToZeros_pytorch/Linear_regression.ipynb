# %%
import torch
import numpy as np

# %%
X_train = torch.FloatTensor([[1],[2],[3]])
y_train = torch.FloatTensor([[2],[4],[6]])

W = torch.zeros(1, requires_grad=True) # requires_grad: 학습할 것이라고 명시
b = torch.zeros(1, requires_grad=True)

# %%
hypothesis = X_train*W+b

# %%
cost = torch.mean((F - y_train) ** 2) # MSE

# %%
from torch import optim
optimizer = optim.SGD([W,b], lr=0.01)

# %%
from torch import optim

X_train = torch.FloatTensor([[1],[2],[3]])
y_train = torch.FloatTensor([[2],[4],[6]])

W = torch.zeros(1, requires_grad=True) # requires_grad: 학습할 것이라고 명시
b = torch.zeros(1, requires_grad=True) 

optimizer = optim.SGD([W,b], lr=0.01)

epochs = 1000

for epoch in range(epochs):
    hypothesis = X_train*W+b
    cost = torch.mean((hypothesis - y_train)**2)
    
    print(f"Epoch: {epoch:4d}, W: {W.item():.3f}, Cost: {cost.item():.6f}")
    
    optimizer.zero_grad() # gradient 초기화
    cost.backward() # gradient 계산
    optimizer.step() # 개선
# Out:
# Epoch:    0, W: 0.000, Cost: 18.666666
# Epoch:    1, W: 0.187, Cost: 14.770963
# Epoch:    2, W: 0.353, Cost: 11.691541
# Epoch:    3, W: 0.500, Cost: 9.257346
# Epoch:    4, W: 0.632, Cost: 7.333169
# Epoch:    5, W: 0.749, Cost: 5.812135
# Epoch:    6, W: 0.853, Cost: 4.609764
# Epoch:    7, W: 0.945, Cost: 3.659278
# Epoch:    8, W: 1.028, Cost: 2.907896
# Epoch:    9, W: 1.101, Cost: 2.313895
# Epoch:   10, W: 1.166, Cost: 1.844294
# Epoch:   11, W: 1.224, Cost: 1.473027
# Epoch:   12, W: 1.276, Cost: 1.179487
# Epoch:   13, W: 1.322, Cost: 0.947386
# Epoch:   14, W: 1.363, Cost: 0.763851
# Epoch:   15, W: 1.400, Cost: 0.618704
# Epoch:   16, W: 1.433, Cost: 0.503902
# Epoch:   17, W: 1.462, Cost: 0.413086
# Epoch:   18, W: 1.488, Cost: 0.341229
# Epoch:   19, W: 1.511, Cost: 0.284360
# Epoch:   20, W: 1.531, Cost: 0.239337
# Epoch:   21, W: 1.550, Cost: 0.203679
# Epoch:   22, W: 1.566, Cost: 0.175424
# Epoch:   23, W: 1.581, Cost: 0.153021
# ...

# %% [markdown]
# ### gradient descent 사용 코드

# %%
X_train = torch.FloatTensor([[1],[2],[3]])
y_train = torch.FloatTensor([[1],[2],[3]])

W = torch.zeros(1)

lr = 0.1

num_epochs = 10

for epoch in range(num_epochs):
    hypothesis = X_train * W
    
    cost = torch.mean((hypothesis - y_train)**2)
    
    gradient = torch.sum((W*X_train - y_train) * X_train)
    
    print(f"Epoch: {epoch:4d}, W: {W.item():.3f}, Cost: {cost.item():.6f}")
    
    W = W - lr*gradient
# Out:
# Epoch:    0, W: 0.000, Cost: 4.666667
# Epoch:    1, W: 1.400, Cost: 0.746666
# Epoch:    2, W: 0.840, Cost: 0.119467
# Epoch:    3, W: 1.064, Cost: 0.019115
# Epoch:    4, W: 0.974, Cost: 0.003058
# Epoch:    5, W: 1.010, Cost: 0.000489
# Epoch:    6, W: 0.996, Cost: 0.000078
# Epoch:    7, W: 1.002, Cost: 0.000013
# Epoch:    8, W: 0.999, Cost: 0.000002
# Epoch:    9, W: 1.000, Cost: 0.000000
